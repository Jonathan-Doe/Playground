# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline

# %%
df = pd.read_csv('sample_searches.csv')
print 'Data shape - {}'.format(df.shape)
df.head()
# Out:
# Data shape - (25200, 16)
#    portal_id searched_date origin destination departure_date return_date  \
# 0         92    2017-01-06    ZYR         BUD     2017-03-23  2017-03-25
# 1         92    2017-01-06    ZYL         DAC     2017-01-25         NaN
# 2        200    2017-01-06    ZWS         NYC     2017-01-22  2017-05-30
# 3         92    2017-01-06    ZWI         SAV     2017-01-10  2017-01-19
# 4         92    2017-01-06    ZWE         NYC     2017-03-26  2017-04-04
#
#    number_of_adults  number_of_children  number_of_seniors  flight_class  \
# 0                 1                   0                  0             1
# 1                 1                   0                  0             1
# 2                 1                   0                  0             1
# 3                 1                   0                  0             1
# 4                 1                   0                  0             1
#
#    cheapest_total_fare  cheapest_engine  \
# 0           271.799988                9
# 1           106.809998                9
# 2           523.660000                9
# 3           372.899994                1
# 4           546.059998                1
#
#                                    unique_airlines country_code        region  \
# 0  AF*KL  KL*AF  AF*SN  KL*SN  AF*LH  KL*LH  AF*AZ           -              -
# 1                                               BG           US    NEW JERSEY
# 2                                            LH AB           -              -
# 3                                        UA  UA*AA           -              -
# 4                                            KL*AF           NL  ZUID-HOLLAND
#
#          city
# 0           -
# 1  WOODBRIDGE
# 2           -
# 3           -
# 4   DORDRECHT

# %% [markdown]
# ## geo features

# %%
airports = pd.read_csv('airports.csv')
remain = ['continent','iso_country','iata_code','longitude_deg','latitude_deg']
airports = airports[remain]
airports = airports.dropna(subset=['iata_code']).drop_duplicates("iata_code")
airports.shape
# Out:
# (9022, 5)

# %%
origin_columns = ['origin_' + x for x in remain ]
airports.columns = origin_columns
df = df.merge(airports,how='left',left_on='origin',right_on = 'origin_iata_code')

destination_columns = ['destination_' + x for x in remain]
airports.columns = destination_columns
df = df.merge(airports,how='left',left_on='destination',right_on = 'destination_iata_code')

# %%
df.head()
# Out:
#    portal_id searched_date origin destination departure_date return_date  \
# 0         92    2017-01-06    ZYR         BUD     2017-03-23  2017-03-25
# 1         92    2017-01-06    ZYL         DAC     2017-01-25         NaN
# 2        200    2017-01-06    ZWS         NYC     2017-01-22  2017-05-30
# 3         92    2017-01-06    ZWI         SAV     2017-01-10  2017-01-19
# 4         92    2017-01-06    ZWE         NYC     2017-03-26  2017-04-04
#
#    number_of_adults  number_of_children  number_of_seniors  flight_class  \
# 0                 1                   0                  0             1
# 1                 1                   0                  0             1
# 2                 1                   0                  0             1
# 3                 1                   0                  0             1
# 4                 1                   0                  0             1
#
#              ...             origin_continent  origin_iso_country  \
# 0            ...                          NaN                 NaN
# 1            ...                           AS                  BD
# 2            ...                          NaN                 NaN
# 3            ...                          NaN                 NaN
# 4            ...                          NaN                 NaN
#
#   origin_iata_code origin_longitude_deg origin_latitude_deg  \
# 0              NaN                  NaN                 NaN
# 1              ZYL            91.866798             24.9632
# 2              NaN                  NaN                 NaN
# 3              NaN                  NaN                 NaN
# 4              NaN                  NaN                 NaN
#
#   destination_continent destination_iso_country destination_iata_code  \
# 0                    EU                      HU                   BUD
# 1                    AS                      BD                   DAC
# 2                   NaN                     NaN                   NaN
# 3                   NaN                      US                   SAV
# 4                   NaN                     NaN                   NaN
#
#   destination_longitude_deg  destination_latitude_deg
# 0                 19.255600                 47.436901
# 1                 90.397783                 23.843347
# 2                       NaN                       NaN
# 3                -81.202103                 32.127602
# 4                       NaN                       NaN
#
# [5 rows x 26 columns]

# %%
airports.head()
# Out:
#      destination_continent destination_iso_country destination_iata_code  \
# 221                     OC                      MH                   UTK
# 437                    NaN                      US                   OCA
# 590                    NaN                      US                   PQS
# 669                    NaN                      US                   CSE
# 1083                   NaN                      US                   JCY
#
#       destination_longitude_deg  destination_latitude_deg
# 221                  169.852005                 11.222000
# 437                  -80.274803                 25.325399
# 590                 -162.899994                 61.934601
# 669                 -106.928341                 38.851918
# 1083                 -98.622498                 30.251801

# %%
df.origin_iata_code.isnull().sum() / float(df.shape[0])
# Out:
# 0.024880952380952382

# %%
df[df.origin_iata_code.isnull()].origin.unique()
# Out:
# array(['ZYR', 'ZWS', 'ZWI', 'ZWE', 'ZVJ', 'ZVE', 'ZFV', 'ZBL', 'YTO',
#        'YMQ', 'YEA', 'XYD', 'XQE', 'XPG', 'XNB', 'XDS', 'WAS', 'TYO',
#        'TCI', 'STO', 'SPK', 'SEL', 'SDZ', 'SAO', 'ROM', 'RIO', 'REK',
#        'QYG', 'QQS', 'QKL', 'PAR', 'OSA', 'NYC', 'MOW', 'MMA', 'MLH',
#        'MIL', 'LON', 'JKT', 'IZM', 'EAP', 'DTT', 'DMS', 'XRF', 'XER',
#        'XDB', 'QQU', 'QQP', 'ZVH', 'TPB', 'EXS', 'QPP', 'PCW', 'TOV'],
#       dtype=object)

# %%
df[df.destination_iata_code.isnull()].destination.unique()
# Out:
# array(['NYC', 'LON', 'YMQ', 'YTO', 'PAR', 'SEL', 'XQE', 'BJS', 'WAS',
#        'MOW', 'BUE', 'TYO', 'RIO', 'MIL', 'DTT', 'ROM', 'CHI', 'JKT',
#        'STO', 'SAO', 'XPG', 'TCI', 'REK', 'OSA', 'QQS', 'IZM', 'BHZ',
#        'SPK', 'ZYR', 'MMA', 'BUH', 'YEA', 'XDB', 'SDZ', 'EAP'],
#       dtype=object)

# %%
airports[airports.destination_iso_country == 'US'].destination_continent = 'North_America'
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# # Check number of unique values for each feature

# %%
df.nunique()
# Out:
# portal_id                 10
# searched_date             14
# origin                  2166
# destination             1587
# departure_date           341
# return_date              342
# number_of_adults           1
# number_of_children         1
# number_of_seniors          1
# flight_class               4
# cheapest_total_fare    20898
# cheapest_engine           17
# unique_airlines        16131
# country_code             152
# region                   331
# city                    1228
# dtype: int64

# %% [markdown]
# # There is only one unique combination for number of passengers: 1 adult, 0 children, 0 seniors.
# ## So we can drop these columns

# %%
df = df.drop(['number_of_adults','number_of_children','number_of_seniors'], axis = 1)

# %% [markdown]
# # Check missing values

# %%
df.isnull().sum() / df.shape[0]
# Out:
# portal_id              0.000000
# searched_date          0.000000
# origin                 0.000000
# destination            0.000000
# departure_date         0.000000
# return_date            0.404008
# flight_class           0.000000
# cheapest_total_fare    0.000000
# cheapest_engine        0.000000
# unique_airlines        0.000000
# country_code           0.000079
# region                 0.000000
# city                   0.000000
# dtype: float64

# %% [markdown]
# ## Here we can see that almost all blanks are return dates
# ## The reason for this is that if returned_date specified - it will be round trip otherwise one-way trip
# ## Create new feature - round_trip, delete return_date

# %%
df['round_trip'] = df.return_date.notnull()
df = df.drop('return_date', axis = 1)

# %% [markdown]
# ## Looks like data were filtered to 1800 samples each day.

# %%
print df.searched_date.value_counts()
# Out:
# 2017-01-08    1800
# 2017-01-09    1800
# 2017-01-02    1800
# 2017-01-03    1800
# 2017-01-01    1800
# 2017-01-06    1800
# 2017-01-07    1800
# 2017-01-04    1800
# 2017-01-05    1800
# 2017-01-11    1800
# 2017-01-10    1800
# 2017-01-13    1800
# 2017-01-12    1800
# 2017-01-14    1800
# Name: searched_date, dtype: int64

# %% [markdown]
# ## There is no price volatility in context of searched day. Looks like searched day (as simple feature) cannot help us to separate samples

# %%
plt.figure(figsize = (16,8))
sns.boxplot(data = df, x = 'searched_date', y = 'cheapest_total_fare')

# %% [markdown]
# ## Usually ticket price depends on preliminary purchase period : the earlier the purchase date  - the cheaper the ticket.
# ## Generate feature period = departure_date - search_date

# %%
df['departure_date'] = pd.to_datetime(df.departure_date, format='%Y-%m-%d')
df['searched_date'] = pd.to_datetime(df.searched_date, format='%Y-%m-%d')
df['period'] = (df.departure_date - df.searched_date).dt.days
df = df.drop(['departure_date','searched_date'], axis = 1)

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x = 'period',y = 'cheapest_total_fare', data = df)

# %% [markdown]
# ## Explore flight_class

# %%
print df.flight_class.value_counts()
fig,ax = plt.subplots(2,1,figsize = (10,8))
ax[0].set_title('Distribution of flight_class')
sns.barplot(x = 'flight_class', y = 'flight_class', data = df, estimator =  lambda i: len(i) / float(len(df)) * 100, ax = ax[0])
ax[0].set(ylabel = 'percent')
plt.tight_layout()
ax[1].set_title('')
sns.boxplot(data = df, x = 'flight_class', y = 'cheapest_total_fare',ax = ax[1] )
# Out:
# 1    24775
# 2      311
# 5       64
# 3       50
# Name: flight_class, dtype: int64

# %% [markdown]
# ## due to small amount of searches with flight class 5 or 3 and significant difference in fare with others - union it in one group.

# %%
df.flight_class = df.flight_class.map({1:1,2:2,3:3,5:3})

# %% [markdown]
# # Explore portal_id

# %%
print df.portal_id.value_counts()
fig,ax = plt.subplots(2,1,figsize = (10,8))
ax[0].set_title('Distribution of portal_id')
sns.barplot(x = 'portal_id', y = 'portal_id', data = df, estimator =  lambda i: len(i) / float(len(df)) * 100, ax = ax[0])
ax[0].set(ylabel = 'percent')
plt.tight_layout()
ax[1].set_title('')
sns.boxplot(data = df, x = 'portal_id', y = 'cheapest_total_fare',ax = ax[1] )
# Out:
# 92     10172
# 95      9952
# 93      2145
# 200     1040
# 91       837
# 115      483
# 201      417
# 204       72
# 85        68
# 96        14
# Name: portal_id, dtype: int64

# %% [markdown]
# ## union portal_ids wit too few occurences into one portal_id

# %%
df.portal_id = df.portal_id.map({92:92,95:95,93:93,200:200,91:91,115:115,201:201,204:0,85:0,96:0})

# %% [markdown]
# ## Explore cheapest_engine

# %%
print df.cheapest_engine.value_counts()
fig,ax = plt.subplots(2,1,figsize = (10,8))
ax[0].set_title('Distribution of cheapest_engine')
sns.barplot(x = 'cheapest_engine', y = 'cheapest_engine', data = df, estimator =  lambda i: len(i) / float(len(df)) * 100, ax = ax[0])
ax[0].set(ylabel = 'percent')
plt.tight_layout()
ax[1].set_title('')
sns.boxplot(data = df, x = 'cheapest_engine', y = 'cheapest_total_fare',ax = ax[1] )
# Out:
# 9      12517
# 1      10363
# 10       872
# 19       813
# 29       222
# 14       111
# 104       58
# 6         53
# 22        49
# 23        38
# 2         32
# 99        25
# 100       22
# 26        12
# 105       10
# 20         2
# 25         1
# Name: cheapest_engine, dtype: int64

# %%
remain = [9,1,10,19]
df.cheapest_engine = df.cheapest_engine.apply(lambda x: x if x in remain else 0)

# %% [markdown]
# ## Origin

# %%
iata = 'ZLO'
print sum(df.origin == iata)
print sum(df.destination == iata)
# Out:
# 14
# 0

# %%
# Out:
# 1

# %%
d1 = df[df.flight_class == 1].cheapest_total_fare
d2 = df[df.flight_class == 2].cheapest_total_fare
d3 = df[df.flight_class == 3].cheapest_total_fare
d4 = df[df.flight_class == 4].cheapest_total_fare
d5 = df[df.flight_class == 5].cheapest_total_fare
sns.kdeplot(d1,)
sns.kdeplot(d2)
sns.kdeplot(d3)
sns.kdeplot(d4)
sns.kdeplot(d5)
plt.show()

# %%
df.flight_class.value_counts()

# %%
df.groupby('flight_class').cheapest_total_fare.mean()

# %%
plt.scatter(df.total_passengers,df.cheapest_total_fare)
plt.show()

# %%
fare = df.cheapest_total_fare.values.mean()

# %%
df['fare'] = df.cheapest_total_fare / fare

# %%
plt.scatter(range(df.shape[0]),df.fare)
plt.show()

# %% [markdown]
# # Define numerical and categorical features

# %%
df.portal_id.value_counts()

# %%
df.origin.unique()

# %%
df.cheapest_engine.unique()

# %%
df['total_passengers'] = df.number_of_adults + df.number_of_children + df.number_of_seniors

# %% [markdown]
# # дата вылета - дата поиска

# %% [markdown]
# # kmodes
